# %% [markdown]
# # Regional sea level — placeholder
#
# A Regional sea-level workflow has not yet been implemented. This page reserves its position in the Jupyter Book without presenting the draft helpers in `functions/cindra_regional_plotting_helpers.py` as published indicators.
#
# Future work should define multi-station UHSLC selection, common quality-control rules, regional aggregation, persistence and reviewed map products before this chapter is expanded.

# %%
# CIndRA notebook display standard
import matplotlib as mpl

mpl.rcParams.update({
    'font.size': 12,
    'axes.titlesize': 15,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 13,
    'figure.dpi': 100,
    'savefig.dpi': 300,
})

# %% [markdown]
# ## Reproducibility notes
#
# This page is a placeholder and performs no calculation. Document the data source, coverage, method and outputs here when the regional sea-level workflow is added.
